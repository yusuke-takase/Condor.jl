# %%
import numpy as np
import healpy as hp
import matplotlib.pylab as plt
import seaborn as sns

# %%
path = "/group/cmb/litebird/usr/ytakase/beam_convolution/devided_maps/"

nside = 512
npix = hp.nside2npix(nside)

# %%
RunRange = 1536
outmap = np.zeros([2, npix])
for i in range(1, RunRange+1):
    outmap += np.load(path+"idx={}.npz".format(i))["convolved_map"]

# %%
hp.mollview(outmap[1], norm="hist")

# %%
using Revise
using Condor
using Falcons
using NPZ
using HDF5
using PyCall
using Healpix
using PyPlot
hp = pyimport("healpy");

# %%
psi_dir = "/group/cmb/litebird/usr/ytakase/psi_db/3_30"
idx = 1
idx_ipix = 1
file = h5open(psi_dir * "/idx=$idx.h5", "r")
psi_in_ipix = read(file,"psi/$idx_ipix");

# %%
plt.hist(rad2deg.(psi_in_ipix), bins=30)
plt.xlabel("Scanning angle [deg]")
plt.ylabel("Number of hits")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(24.000000000000007, 0.5, 'Number of hits')

# %%
data = npzread("/home/cmb/yusuket/program/beam_study/npz_beamdata/MFT_88.5GHz_000.0_166.7_xpol_v2.npz")
Nx = 360
Ny = 721
beam2d, x, y = get_2Ddata(data, Nx, Ny);

# %%
plt.figure(figsize=(6,6))
#plt.title("MFT_88.5GHz_000.0_166.7_xpol_v2")
plt.title("MFT_88.5GHz_166.7mm_edge, Hiroaki")
plt.xlabel("deg.")
plt.ylabel("deg.")
plt.pcolormesh(x, y, 10log10.(beam2d), cmap = "jet" )
plt.axes().set_aspect("equal")
plt.colorbar( orientation ="vertical")

effective_beam = symmetrizer(psi_in_ipix, beam2d, Nx, Ny)
plt.figure(figsize=(6,6))
plt.title("MFT_88.5GHz_000.0_166.7_xpol_v2, Effective")
plt.xlabel("deg.")
plt.ylabel("deg.")
plt.pcolormesh(x, y, 10log10.(effective_beam), cmap = "jet" )
plt.axes().set_aspect("equal")
plt.colorbar( orientation ="vertical")
# Out:
# Figure(PyObject <Figure size 600x600 with 2 Axes>)
# Figure(PyObject <Figure size 600x600 with 2 Axes>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x7fc3296fc880>

# %%
nside = 512
npix = nside2npix(nside)
res = Resolution(nside)
# Out:
# Healpix resolution(NSIDE = 512)

# %%
target_pixel = ang2pixRing(res, deg2rad(0), deg2rad(18))
beammap = gen_beammap(res, effective_beam, target_pixel)

hp.mollview(dBi(beammap), norm="none", rot=(0,0))
hp.graticule()
# Out:
# Figure(PyObject <Figure size 850x540 with 2 Axes>)

# %%
cmb_path = "/home/cmb/yusuket/program/MapData/Nside512/lensed_r0_512_non_smooth.fits"
cmbmap = hp.read_map(cmb_path, field=(0,1,2));
cmbmap = hp.ud_grade(cmbmap, nside)
lmax = 3nside - 1 
weight_path = "/home/cmb/yusuket/program/MapData/healpy-data/."
alm = hp.map2alm(cmbmap, lmax = lmax, datapath = weight_path, use_pixel_weights=true);

# %%
skyalm = AlmPair(alm, conj.(alm))
Blm = gen_Blm(res, beammap, weight_path);

# %%
convolved_map = EffectiveBeamConvolution(res, skyalm, beam2d, 1, psi_dir, weight_path)
# Out:
# ariaOfPixels : 2048
# Run range of idx : 1 --> 1536
# Progress:   0%|▏                                        |  ETA: 0:56:35
# InterruptException:
#
# Stacktrace:
#   [1] sigatomic_end
#     @ ./c.jl:437 [inlined]
#   [2] disable_sigint
#     @ ./c.jl:460 [inlined]
#   [3] __pycall!
#     @ ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:42 [inlined]
#   [4] _pycall!(ret::PyObject, o::PyObject, args::Tuple{Matrix{Float64}}, nargs::Int64, kw::PyObject)
#     @ PyCall ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:29
#   [5] _pycall!(ret::PyObject, o::PyObject, args::Tuple{Matrix{Float64}}, kwargs::Base.Iterators.Pairs{Symbol, Any, Tuple{Symbol, Symbol, Symbol}, NamedTuple{(:lmax, :datapath, :use_pixel_weights), Tuple{Int64, String, Bool}}})
#     @ PyCall ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:11
#   [6] #_#114
#     @ ~/.julia/packages/PyCall/BD546/src/pyfncall.jl:86 [inlined]
#   [7] gen_Blm(res::Resolution, beammap::Vector{Float64}, weight_path::String)
#     @ Condor /gpfs/home/cmb/yusuket/program/beam_study/git_repo/Condor/src/function/beam_func.jl:80
#   [8] macro expansion
#     @ /gpfs/home/cmb/yusuket/program/beam_study/git_repo/Condor/src/function/convolution_func.jl:29 [inlined]
#   [9] macro expansion
#     @ ./timing.jl:210 [inlined]
#  [10] EffectiveBeamConvolution(res::Resolution, sky::AlmPair{Matrix{ComplexF64}}, beam2d::LinearAlgebra.Adjoint{Float64, Matrix{Float64}}, idx::Int64, psi_dir::String, weight_path::String)
#     @ Condor /gpfs/home/cmb/yusuket/program/beam_study/git_repo/Condor/src/function/convolution_func.jl:24
#  [11] top-level scope
#     @ In[33]:1
#  [12] eval
#     @ ./boot.jl:360 [inlined]
#  [13] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1094
